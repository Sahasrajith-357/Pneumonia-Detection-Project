# %%
import numpy as np
import tensorflow as tf
import keras

from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image
from sklearn.utils.class_weight import compute_class_weight
from sklearn.model_selection import train_test_split


import tensorflow as tf
import keras
from keras.applications import InceptionV3
from keras.optimizers import Adam
from tensorflow.keras.losses import BinaryCrossentropy
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.models import load_model

from sklearn.metrics import confusion_matrix, precision_score, recall_score, f1_score



import matplotlib.pyplot as plt

# %%
#IMAGE PREPROCESSING

#converting the images to numpy arrays
def image_to_array(directory, target_size) :
        datagen = ImageDataGenerator()
        dataset_df = datagen.flow_from_directory(f'chest_xray/{directory}',
                                                classes = ['NORMAL', 'PNEUMONIA'],
                                                batch_size = 1,
                                                class_mode = 'binary',
                                                shuffle = False,
                                                target_size = (target_size, target_size)
                                                )
        
        images_df, labels_df = [], []   
        for _ in range(len(dataset_df)) :
            imgs , lbls = next(dataset_df)
            images_df.append(imgs)
            labels_df.append(lbls)
        images_df = np.squeeze(np.array(images_df)) #removing the extra dimension (batch size)
        labels_df = np.array(labels_df).flatten()   #train_test_split requires an array of shape (num_labels,) and not a 2d array  
        return images_df, labels_df


#rescaling the images => pixels rescaled between to values in range(0,1)
def rescale(x, y, shuffle_mode) :
    datagen = ImageDataGenerator(rescale=1/255)
    dataset = datagen.flow(x=x,        #for training the model shuffle the training sets so that the model doesnt learn order of images
                          y=y,         #experiment with batch size, reduce if resource gets exhausted    
                          batch_size=16,
                          shuffle=shuffle_mode)
    return dataset


#calculating class weights for dealing with imbalanced data sets
def class_weights(labels): 
    nb_pneumonia = np.count_nonzero(labels)    
    nb_normal = np.count_nonzero(labels==0)    
    
    class_weight_0 = (1/nb_normal)*((nb_pneumonia+nb_normal)/2)   #formula taken from tensorflow documentation
    class_weight_1 = (1/nb_pneumonia)*((nb_pneumonia+nb_normal)/2)
    return {0:class_weight_0, 1:class_weight_1}  


#loading images and labels 
images_df_train, labels_df_train = image_to_array('train', 224)
images_df_test, labels_df_test = image_to_array('test', 224)

#splitting the images to train and validation sets
cxr_train_img, cxr_val_img, cxr_train_label, cxr_val_label = train_test_split(images_df_train, labels_df_train, test_size=0.2, shuffle=True, random_state=42)
#Random_state=42 ensures that the shuffle is specific, random_state can be 0, 1 ..., keep experimenting for better accuracies
   
#class weights
class_weight = class_weights(cxr_train_label)

#rescaled datasets 
trainy = rescale(cxr_train_img, cxr_train_label, True) #for training the model shuffle the training sets so that the model doesnt learn order of images
valy = rescale(cxr_val_img, cxr_val_label, False)  #for validation do not shuffle since every epoch would result in a different accuracy and loss that wouldnt converge                                        
testy = rescale(images_df_test, labels_df_test, False) #for testing the model
# Out:
# Found 5216 images belonging to 2 classes.
# Found 624 images belonging to 2 classes.

# %%
#VISUALIZING THE DATA
from PIL import Image
plt.figure(figsize=(10, 10), dpi = 150)

# Select random indices
indices = np.random.choice(range(len(cxr_train_label)), 9, replace=False)

for i, j in enumerate(indices):
    position = plt.subplot(3, 3, i + 1)
    # Convert numpy array to image and display
    img = Image.fromarray((cxr_train_img[j] * 255).astype(np.uint8))  
    plt.imshow(img)
    label = "NORMAL" if cxr_train_label[j] == 0 else "PNEUMONIA"
    plt.title(label, fontsize=5)
    plt.axis("off")

plt.tight_layout()
plt.show()

# %%
#BUILDING THE CNN MODEL
image_size = (224,224,3)
inputs = keras.Input(shape=image_size)

inception = InceptionV3(include_top=False, weights='imagenet', input_shape=image_size)
inception.trainable = False  #freezing the base model
x = inception(inputs, training=False) #inference mode
x = keras.layers.GlobalAveragePooling2D()(x)
outputs = keras.layers.Dense(units = 1, activation= 'sigmoid')(x)  #customized classifier
ensemble_model = keras.models.Model(inputs, outputs)

ensemble_model.summary(show_trainable=True)
# Out:
# Model: "model"
# ____________________________________________________________________________
#  Layer (type)                Output Shape              Param #   Trainable
# ============================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0         Y
#
#  inception_v3 (Functional)   (None, 5, 5, 2048)        21802784  N
#
#  global_average_pooling2d (G  (None, 2048)             0         Y
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 1)                 2049      Y
#
# ============================================================================
# Total params: 21,804,833
# Trainable params: 2,049
# Non-trainable params: 21,802,784
# ____________________________________________________________________________

# %%
#CHECKING IF GPU IS BEING UTILIZED
print(tf.config.experimental.list_physical_devices('GPU'))
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
#COMPILING AND TRAINING THE MODEL
optimizer = Adam(learning_rate = 1e-4)
loss = BinaryCrossentropy()
model_checkpoint = ModelCheckpoint(filepath = 'comparison/inception_224.h5',
                                   monitor = 'val_loss',
                                   save_best_only = True,
                                   mode = 'min',
                                   verbose = 1)

ensemble_model.compile(optimizer = optimizer, loss = loss, metrics = ['accuracy'] )

history = ensemble_model.fit(x = trainy, validation_data = valy, epochs = 25, callbacks=[model_checkpoint], class_weight=class_weight)
# Out:
# Epoch 1/25
# 261/261 [==============================] - ETA: 0s - loss: 0.4757 - accuracy: 0.7862
# Epoch 1: val_loss improved from inf to 0.40058, saving model to comparison\inception_224.h5
# 261/261 [==============================] - 33s 80ms/step - loss: 0.4757 - accuracy: 0.7862 - val_loss: 0.4006 - val_accuracy: 0.8276
# Epoch 2/25
# 261/261 [==============================] - ETA: 0s - loss: 0.3279 - accuracy: 0.8682
# Epoch 2: val_loss improved from 0.40058 to 0.32732, saving model to comparison\inception_224.h5
# 261/261 [==============================] - 19s 73ms/step - loss: 0.3279 - accuracy: 0.8682 - val_loss: 0.3273 - val_accuracy: 0.8544
# Epoch 3/25
# 261/261 [==============================] - ETA: 0s - loss: 0.2746 - accuracy: 0.8888
# Epoch 3: val_loss improved from 0.32732 to 0.28772, saving model to comparison\inception_224.h5
# 261/261 [==============================] - 19s 74ms/step - loss: 0.2746 - accuracy: 0.8888 - val_loss: 0.2877 - val_accuracy: 0.8716
# Epoch 4/25
# 261/261 [==============================] - ETA: 0s - loss: 0.2445 - accuracy: 0.9051
# Epoch 4: val_loss improved from 0.28772 to 0.26841, saving model to comparison\inception_224.h5
# 261/261 [==============================] - 21s 79ms/step - loss: 0.2445 - accuracy: 0.9051 - val_loss: 0.2684 - val_accuracy: 0.8764
# Epoch 5/25
# 261/261 [==============================] - ETA: 0s - loss: 0.2240 - accuracy: 0.9161
# Epoch 5: val_loss improved from 0.26841 to 0.21585, saving model to comparison\inception_224.h5
# 261/261 [==============================] - 20s 78ms/step - loss: 0.2240 - accuracy: 0.9161 - val_loss: 0.2159 - val_accuracy: 0.9157
# Epoch 6/25
# 261/261 [==============================] - ETA: 0s - loss: 0.2095 - accuracy: 0.9228
# Epoch 6: val_loss did not improve from 0.21585
# 261/261 [==============================] - 19s 74ms/step - loss: 0.2095 - accuracy: 0.9228 - val_loss: 0.2307 - val_accuracy: 0.8985
# Epoch 7/25
# 261/261 [==============================] - ETA: 0s - loss: 0.1975 - accuracy: 0.9271
# Epoch 7: val_loss did not improve from 0.21585
# 261/261 [==============================] - 19s 72ms/step - loss: 0.1975 - accuracy: 0.9271 - val_loss: 0.2238 - val_accuracy: 0.8994
# Epoch 8/25
# 261/261 [==============================] - ETA: 0s - loss: 0.1878 - accuracy: 0.9300
# Epoch 8: val_loss improved from 0.21585 to 0.19857, saving model to comparison\inception_224.h5
# 261/261 [==============================] - 19s 75ms/step - loss: 0.1878 - accuracy: 0.9300 - val_loss: 0.1986 - val_accuracy: 0.9167
# Epoch 9/25
# 261/261 [==============================] - ETA: 0s - loss: 0.1797 - accuracy: 0.9336
# Epoch 9: val_loss improved from 0.19857 to 0.19019, saving model to comparison\inception_224.h5
# 261/261 [==============================] - 20s 75ms/step - loss: 0.1797 - accuracy: 0.9336 - val_loss: 0.1902 - val_accuracy: 0.9224
# Epoch 10/25
# 261/261 [==============================] - ETA: 0s - loss: 0.1723 - accuracy: 0.9377
# Epoch 10: val_loss did not improve from 0.19019
# 261/261 [==============================] - 19s 73ms/step - loss: 0.1723 - accuracy: 0.9377 - val_loss: 0.1974 - val_accuracy: 0.9119
# Epoch 11/25
# 261/261 [==============================] - ETA: 0s - loss: 0.1662 - accuracy: 0.9386
# Epoch 11: val_loss improved from 0.19019 to 0.17619, saving model to comparison\inception_224.h5
# 261/261 [==============================] - 20s 76ms/step - loss: 0.1662 - accuracy: 0.9386 - val_loss: 0.1762 - val_accuracy: 0.9282
# Epoch 12/25
# 261/261 [==============================] - ETA: 0s - loss: 0.1618 - accuracy: 0.9398
# Epoch 12: val_loss improved from 0.17619 to 0.16728, saving model to comparison\inception_224.h5
# 261/261 [==============================] - 21s 81ms/step - loss: 0.1618 - accuracy: 0.9398 - val_loss: 0.1673 - val_accuracy: 0.9368
# Epoch 13/25
# 261/261 [==============================] - ETA: 0s - loss: 0.1566 - accuracy: 0.9418
# Epoch 13: val_loss improved from 0.16728 to 0.15982, saving model to comparison\inception_224.h5
# 261/261 [==============================] - 20s 75ms/step - loss: 0.1566 - accuracy: 0.9418 - val_loss: 0.1598 - val_accuracy: 0.9435
# Epoch 14/25
# 261/261 [==============================] - ETA: 0s - loss: 0.1522 - accuracy: 0.9406
# Epoch 14: val_loss did not improve from 0.15982
# 261/261 [==============================] - 19s 74ms/step - loss: 0.1522 - accuracy: 0.9406 - val_loss: 0.1711 - val_accuracy: 0.9330
# Epoch 15/25
# 261/261 [==============================] - ETA: 0s - loss: 0.1496 - accuracy: 0.9444
# Epoch 15: val_loss did not improve from 0.15982
# 261/261 [==============================] - 19s 74ms/step - loss: 0.1496 - accuracy: 0.9444 - val_loss: 0.1614 - val_accuracy: 0.9387
# Epoch 16/25
# 261/261 [==============================] - ETA: 0s - loss: 0.1457 - accuracy: 0.9446
# Epoch 16: val_loss did not improve from 0.15982
# 261/261 [==============================] - 20s 77ms/step - loss: 0.1457 - accuracy: 0.9446 - val_loss: 0.1604 - val_accuracy: 0.9387
# Epoch 17/25
# 261/261 [==============================] - ETA: 0s - loss: 0.1422 - accuracy: 0.9470
# Epoch 17: val_loss did not improve from 0.15982
# 261/261 [==============================] - 20s 75ms/step - loss: 0.1422 - accuracy: 0.9470 - val_loss: 0.1650 - val_accuracy: 0.9377
# Epoch 18/25
# 261/261 [==============================] - ETA: 0s - loss: 0.1392 - accuracy: 0.9494
# Epoch 18: val_loss did not improve from 0.15982
# 261/261 [==============================] - 20s 76ms/step - loss: 0.1392 - accuracy: 0.9494 - val_loss: 0.1634 - val_accuracy: 0.9368
# Epoch 19/25
# 261/261 [==============================] - ETA: 0s - loss: 0.1371 - accuracy: 0.9504
# Epoch 19: val_loss did not improve from 0.15982
# 261/261 [==============================] - 20s 75ms/step - loss: 0.1371 - accuracy: 0.9504 - val_loss: 0.1723 - val_accuracy: 0.9262
# Epoch 20/25
# 261/261 [==============================] - ETA: 0s - loss: 0.1352 - accuracy: 0.9485
# Epoch 20: val_loss improved from 0.15982 to 0.15323, saving model to comparison\inception_224.h5
# 261/261 [==============================] - 20s 77ms/step - loss: 0.1352 - accuracy: 0.9485 - val_loss: 0.1532 - val_accuracy: 0.9416
# Epoch 21/25
# 261/261 [==============================] - ETA: 0s - loss: 0.1323 - accuracy: 0.9518
# Epoch 21: val_loss improved from 0.15323 to 0.15272, saving model to comparison\inception_224.h5
# 261/261 [==============================] - 20s 78ms/step - loss: 0.1323 - accuracy: 0.9518 - val_loss: 0.1527 - val_accuracy: 0.9435
# Epoch 22/25
# 261/261 [==============================] - ETA: 0s - loss: 0.1307 - accuracy: 0.9516
# Epoch 22: val_loss improved from 0.15272 to 0.14941, saving model to comparison\inception_224.h5
# 261/261 [==============================] - 20s 78ms/step - loss: 0.1307 - accuracy: 0.9516 - val_loss: 0.1494 - val_accuracy: 0.9425
# Epoch 23/25
# 261/261 [==============================] - ETA: 0s - loss: 0.1288 - accuracy: 0.9540
# Epoch 23: val_loss improved from 0.14941 to 0.13692, saving model to comparison\inception_224.h5
# 261/261 [==============================] - 21s 79ms/step - loss: 0.1288 - accuracy: 0.9540 - val_loss: 0.1369 - val_accuracy: 0.9492
# Epoch 24/25
# 261/261 [==============================] - ETA: 0s - loss: 0.1271 - accuracy: 0.9537
# Epoch 24: val_loss did not improve from 0.13692
# 261/261 [==============================] - 20s 76ms/step - loss: 0.1271 - accuracy: 0.9537 - val_loss: 0.1428 - val_accuracy: 0.9454
# Epoch 25/25
# 261/261 [==============================] - ETA: 0s - loss: 0.1245 - accuracy: 0.9545
# Epoch 25: val_loss did not improve from 0.13692
# 261/261 [==============================] - 20s 76ms/step - loss: 0.1245 - accuracy: 0.9545 - val_loss: 0.1375 - val_accuracy: 0.9502

# %%
#EVALUATING THE PERFORMANCE OF THE TRAINED MODEL
trained_model = load_model(r'comparison\inception_224.h5')
trained_model.evaluate(testy, return_dict=True)
# Out:
# 39/39 [==============================] - 3s 58ms/step - loss: 0.4506 - accuracy: 0.8253
# {'loss': 0.45056840777397156, 'accuracy': 0.8253205418586731}

# %%
#FINETUNING THE MODEL
optimizer = Adam(learning_rate = 1e-5)  #using a low learning rate
loss = BinaryCrossentropy()
model_checkpoint = ModelCheckpoint(filepath = 'comparison/inception_224_finetuned.h5',
                                   monitor = 'val_loss',
                                   save_best_only = True,
                                   mode = 'min',
                                   verbose = 1)

inception.trainable = True   #unfreezing the base model layers
ensemble_model.compile(optimizer = optimizer, loss = loss, metrics = ['accuracy'] )
history2 = ensemble_model.fit(x = trainy, validation_data = valy, epochs = 1, callbacks=[model_checkpoint], class_weight=class_weight)
# Out:
# 261/261 [==============================] - ETA: 0s - loss: 0.1099 - accuracy: 0.9593
# Epoch 1: val_loss improved from inf to 0.07091, saving model to comparison\inception_224_finetuned.h5
# 261/261 [==============================] - 59s 189ms/step - loss: 0.1099 - accuracy: 0.9593 - val_loss: 0.0709 - val_accuracy: 0.9732

# %%
finetuned_model = load_model(r'comparison\inception_224_finetuned.h5')

# %%
#EVALUATING THE FINETUNED MODEL
finetuned_model.evaluate(testy, return_dict=True)
# Out:
# 39/39 [==============================] - 4s 58ms/step - loss: 0.4855 - accuracy: 0.8462
# {'loss': 0.4854675829410553, 'accuracy': 0.8461538553237915}

# %%
#ARCHITECTURE OF THE MODEL USED
finetuned_model.summary(show_trainable=True)
# Out:
# Model: "model"
# ____________________________________________________________________________
#  Layer (type)                Output Shape              Param #   Trainable
# ============================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0         Y
#
#  inception_v3 (Functional)   (None, 5, 5, 2048)        21802784  Y
#
#  global_average_pooling2d (G  (None, 2048)             0         Y
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 1)                 2049      Y
#
# ============================================================================
# Total params: 21,804,833
# Trainable params: 21,770,401
# Non-trainable params: 34,432
# ____________________________________________________________________________

# %%
#TESTING THE FINE TUNED MODEL ON THE TEST SET
y_pred = finetuned_model.predict(testy)
y_pred = (y_pred>0.5).astype(int)  
y_true = labels_df_test.reshape(len(labels_df_test),1) 

#PERFORMANCE METRICS : PRECISION, RECALL, F1 SCORE
precision = precision_score(y_true, y_pred)
recall = recall_score(y_true, y_pred)
f1 = f1_score(y_true, y_pred)
cm = confusion_matrix(y_true, y_pred)

print(f'Precision : {precision}')
print(f'Recall : {recall}')
print(f"F1 Score : {f1}")
print(cm)
# Out:
# 39/39 [==============================] - 3s 55ms/step
# Precision : 0.8075313807531381
# Recall : 0.9897435897435898
# F1 Score : 0.8894009216589862
# [[142  92]
#  [  4 386]]

# %%
#PLOTTING TRAINING VS VALIDATION LOSS, ACCURACY GRAPHS
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'b', label='training_loss')
plt.plot(epochs, val_loss, 'r', label='validation_loss')
plt.title('Trained Model Training and Validation')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']
epochs = range(1, len(accuracy) + 1)
plt.plot(epochs, accuracy, 'b', label='training_accuracy')
plt.plot(epochs, val_accuracy, 'r', label='validation_accuracy')
plt.title('Trained Model Training and Validation')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
#TESTING THE MODEL ON A SMALLER DATASET
datagen = ImageDataGenerator(rescale=1/255)
small_testset = datagen.flow_from_directory('chest_xray/val',
                                          batch_size = 1,
                                          class_mode = 'binary',
                                          shuffle = False,
                                          target_size = (224,224))
y_pred = finetuned_model.predict(small_testset)
y_pred = (y_pred>0.5).astype('uint8')
y_pred = np.array(y_pred).flatten()
y_true = small_testset.classes
# Out:
# Found 16 images belonging to 2 classes.
# 16/16 [==============================] - 1s 17ms/step

# %%
#PERFORMANCE METRICS : PRECISION, RECALL, F1 SCORE
precision = precision_score(y_true, y_pred)
recall = recall_score(y_true, y_pred)
f1 = f1_score(y_true, y_pred)
cm = confusion_matrix(y_true, y_pred)

print(f'Precision : {precision}')
print(f'Recall : {recall}')
print(f"F1 Score : {f1}")
print(cm)
# Out:
# Precision : 0.8888888888888888
# Recall : 1.0
# F1 Score : 0.9411764705882353
# [[7 1]
#  [0 8]]

# %%
#VISUALIZING SOME PREDICTIONS
plt.figure(figsize=(10, 10), dpi=150)
indices = np.random.choice(range(len(y_pred)), 9, replace=False)

for i, j in enumerate(indices):
    position = plt.subplot(3, 3, i + 1)
    img = Image.fromarray((small_testset[j][0][0] * 255).astype(np.uint8)) 
    plt.imshow(img)
    # Get the true label and predicted label
    true_label = "NORMAL" if y_true[j] == 0 else "PNEUMONIA"
    pred_label = "NORMAL" if y_pred[j] == 0 else "PNEUMONIA"
    
    plt.title(f"True: {true_label}\nPred: {pred_label}", fontsize=10)
    plt.axis("off")

plt.tight_layout()
plt.show()
